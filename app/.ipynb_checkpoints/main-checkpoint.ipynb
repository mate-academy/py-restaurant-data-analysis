# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %% [markdown]
# # Task 0
# Data extraction: get the data from 3 tables & combine it into single `.csv` file.
# After that read this file using pandas to create Dataframe.
# So it will be all joined data in 1 dataframe. Quick check - should be 74818 rows in it.

# %%
conn = sqlite3.connect('db.sqlite3')

sql_query_combined = """SELECT
                            restaurant_orderitem.order_id AS OrderID,
                            restaurant_product.name AS Name,
                            restaurant_product.price AS Price,
                            restaurant_orderitem.quantity AS Quantity,
                            restaurant_order.datetime AS Date
                        FROM restaurant_orderitem
                        LEFT JOIN restaurant_order
                        ON restaurant_orderitem.order_id = restaurant_order.id
                        LEFT JOIN restaurant_product
                        ON restaurant_orderitem.product_id = restaurant_product.id
                      """
df = pd.read_sql_query(sql_query_combined, conn)
df.to_csv('data.csv', index=False)
df = pd.read_csv('data.csv', low_memory=False)
conn.close()

df.head()
# Out:
#    OrderID                 Name  Price  Quantity                 Date
# 0        1        Plain Papadum   0.80         2  2019-08-03 20:25:00
# 1        1     King Prawn Balti  12.95         1  2019-08-03 20:25:00
# 2        1          Garlic Naan   2.95         1  2019-08-03 20:25:00
# 3        1        Mushroom Rice   3.95         1  2019-08-03 20:25:00
# 4        1  Paneer Tikka Masala   8.95         1  2019-08-03 20:25:00

# %% [markdown]
# # Task 1
# Get Top 10 most popular products in restaurant sold by Quantity.
# Count how many times each product was sold and create a pie chart with percentage of popularity (by quantity) for top 10 of them.
#
# Example:
#
# ![pie chart](../demo/pie.png)

# %%
top_ten_products = df.sort_values(["Quantity"], ascending=False).head(10)
plt.pie(top_ten_products["Quantity"], labels=top_ten_products["Name"], autopct="%1.1f%%")
plt.title("Top 10 positions in menu by quantity")
plt.figure(figsize=[15, 7])

# %% [markdown]
# # Task 2
# Calculate `Item Price` (Product Price * Quantity) for each Order Item in dataframe.
# And Make the same Top 10 pie chart, but this time by `Item Price`. So this chart should describe not the most popular products by quantity, but which products (top 10) make the most money for restaurant. It should be also with percentage.

# %%
df["ItemPrice"] = df["Price"] * df["Quantity"]
item_prices = df.groupby("Name")["ItemPrice"].sum()
top_ten_item_prices = item_prices.sort_values(ascending=False).head(10)
plt.pie(top_ten_item_prices, labels=top_ten_item_prices.index, autopct="%1.1f%%")
plt.title("Top 10 positions in menu by amount of money they make for restaurant")
plt.figure(figsize=[15, 7])

# %% [markdown]
# # Task 3
# Calculate `Order Hour` based on `Order Datetime`, which will tell about the specific our the order was created (from 0 to 23). Using `Order Hour` create a bar chart, which will tell the total restaurant income based on the hour order was created. So on x-axis - it will be values from 0 to 23 (hours), on y-axis - it will be the total sum of order prices, which were sold on that hour.
#
# Example:
#
# ![bar chart](../demo/bar.png)

# %%
df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
df["OrderHour"] = df["Date"].dt.hour

hourly_income = df.groupby("OrderHour")["ItemPrice"].sum()

plt.figure(figsize=(12, 6))
plt.bar(hourly_income.index, hourly_income.values, color="blue")
plt.xlabel("Order Hour")
plt.ylabel("Total Income")
plt.title("Total Restaurant Income by Order Hour")
plt.xticks(range(24))
# Out:
# ([<matplotlib.axis.XTick at 0x7fd5cd34db70>,
# ...
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17'),
#   Text(18, 0, '18'),
#   Text(19, 0, '19'),
#   Text(20, 0, '20'),
#   Text(21, 0, '21'),
#   Text(22, 0, '22'),
#   Text(23, 0, '23')])

# %% [markdown]
# # Task 4
# Make similar bar chart, but right now with `Order Day Of The Week` (from Monday to Sunday), and also analyze total restaurant income by each day of the week.

# %%
df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

df["OrderDayOfWeek"] = df["Date"].dt.dayofweek

daily_income = df.groupby("OrderDayOfWeek")["ItemPrice"].sum()

day_names = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
daily_income.index = day_names

plt.figure(figsize=(10, 6))
plt.bar(daily_income.index, daily_income.values, color="green")
plt.xlabel("Order Day of the Week")
plt.ylabel("Total Income")
plt.title("Total Restaurant Income by Day of the Week")
# Out:
# Text(0.5, 1.0, 'Total Restaurant Income by Day of the Week')
